# %% [markdown]
# ## Table of contents
#
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ### Introduction : Business Problem <a name="introduction"></a>

# %% [markdown]
# During these unprecedented times with Pandemic. Medical supplies are utmost required in most populated places in New York City. In this project we are trying to find the optimal location for opening a Pharmacy in the borough of Brooklyn.
#
# Since the borough has a lot of pharmacies already we need to find a location with less density of pharmacies in a neighborhood.
#
# We will use data science techniques to generate the most promising neighborhoods. This will give the stakeholders boroughs with less number of pharmacies so that they can shortlist and review other characterestics

# %% [markdown]
# ### Data <a name="data"></a>

# %% [markdown]
# Based on definition of our problem, factors that will influence our decission will be:
#
# * Number of pharmacies in the neighborhood.
#
# Following data sources will be needed to extract/generate the required information:
#
# * Extract NYC Neighborhoods from Wiki : https://en.wikipedia.org/wiki/Neighborhoods_in_New_York_City
# * centers of candidate areas will be generated algorithmically.
# * Number of Pharmacies and their type and location in every neighborhood will be obtained using **Foursquare API**

# %%
# Use Beautiful Soup Object to do Web Scraping of the URL
# !pip install beautifulsoup4
from bs4 import BeautifulSoup
import pandas as pd
from urllib.request import urlopen
from geopy.geocoders import Nominatim # Convert Address to Latitude and Longitude Values
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

url = "https://en.wikipedia.org/wiki/Neighborhoods_in_New_York_City"
page = urlopen(url)
html = page.read().decode("utf-8")
soup = BeautifulSoup(html, "html.parser")
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4) (2.0.1)

# %% [markdown]
# #### Now do Web Scraping and extract NYC neighborhoods from Wikipedia Communityboards

# %%
table = soup.find('table', attrs={'class':'wikitable sortable'})
table_body = table.find('tbody')
rows = table_body.find_all('tr')
#for row in rows:
#    cols = row.find_all('td')
#    cols = [ele.text.strip() for ele in cols]
#    data.append([ele for ele in cols if ele]) # Get rid of empty values
#data

# Define Column Names for Dataframe
column_names = ['CommunityBoard','Area', 'Census', 'Neighborhood']
#Instantiate the dataframe
neighbourhoods = pd.DataFrame(columns=column_names)
for row in rows:
    tds = row.find_all('td')
    cb = ''
    area =''
    cns=''
    nbd=''
    for n, td in enumerate(tds):
        #print(f"index {n}: {td.text.strip()}")
        if n == 0: cb = td.text.replace('\n', '')  
        if n == 1: area = td.text.replace('\n', '')  
        if n == 2: cns = td.text.replace('\n', '')  
        if n == 4: nbd = td.text.replace('\n', '')  
    neighbourhoods = neighbourhoods.append({ 'CommunityBoard' : cb,
                                              'Area' : area,
                                              'Census' : cns, 
                                              'Neighborhood' : nbd  }, ignore_index=True)
indexNames = neighbourhoods[ neighbourhoods['CommunityBoard'] == 'New York City' ].index
neighbourhoods.drop(indexNames , inplace=True)
neighbourhoods.head()
# Out:
#   CommunityBoard  Area   Census  \
# 0
# 1     Bronx CB 1  7.17   91,497
# 2     Bronx CB 2  5.54   52,246
# 3     Bronx CB 3  4.07   79,762
# 4     Bronx CB 4  5.28  146,441
#
#                                         Neighborhood
# 0
# 1                   Melrose, Mott Haven, Port Morris
# 2                              Hunts Point, Longwood
# 3  Claremont, Concourse Village, Crotona Park, Mo...
# 4                              Concourse, Highbridge

# %% [markdown]
# #### Now transpose neighborhoods to make it individual rows

# %%
# One Way to Explode and reset the index to avoid duplicate index names

neighbourhoods_exp=neighbourhoods.assign(Neighborhood=neighbourhoods['Neighborhood']
                                            .str.split(',')).explode('Neighborhood').reset_index(drop=True)
neighbourhoods_exp
# Out:
#          CommunityBoard   Area   Census      Neighborhood
# 0
# 1            Bronx CB 1   7.17   91,497           Melrose
# 2            Bronx CB 1   7.17   91,497        Mott Haven
# 3            Bronx CB 1   7.17   91,497       Port Morris
# 4            Bronx CB 2   5.54   52,246       Hunts Point
# ..                  ...    ...      ...               ...
# 326  Staten Island CB 3  58.97  152,908      Prince's Bay
# 327  Staten Island CB 3  58.97  152,908   Richmond Valley
# 328  Staten Island CB 3  58.97  152,908         Rossville
# 329  Staten Island CB 3  58.97  152,908       Tottenville
# 330  Staten Island CB 3  58.97  152,908           Woodrow
#
# [331 rows x 4 columns]

# %% [markdown]
# #### Extract Borough Names from Community Board

# %%
neighbourhoods_exp['Borough'] = neighbourhoods_exp['CommunityBoard'].str.split().str[0]
neighbourhoods_exp
# Out:
#          CommunityBoard   Area   Census      Neighborhood Borough
# 0                                                             NaN
# 1            Bronx CB 1   7.17   91,497           Melrose   Bronx
# 2            Bronx CB 1   7.17   91,497        Mott Haven   Bronx
# 3            Bronx CB 1   7.17   91,497       Port Morris   Bronx
# 4            Bronx CB 2   5.54   52,246       Hunts Point   Bronx
# ..                  ...    ...      ...               ...     ...
# 326  Staten Island CB 3  58.97  152,908      Prince's Bay  Staten
# 327  Staten Island CB 3  58.97  152,908   Richmond Valley  Staten
# 328  Staten Island CB 3  58.97  152,908         Rossville  Staten
# 329  Staten Island CB 3  58.97  152,908       Tottenville  Staten
# 330  Staten Island CB 3  58.97  152,908           Woodrow  Staten
#
# [331 rows x 5 columns]

# %% [markdown]
# #### Enrich the Data Set with Latitude And Longitude

# %%
col01 =column_names = ['Borough','CommunityBoard','Area', 'Census', 'Neighborhood','Latitude', 'Longitude']
#Instantiate the dataframe
geo_bor = pd.DataFrame(columns=col01)
t_Borough = ''
for index, row in neighbourhoods_exp.iterrows():
    t_CommunityBoard = row['CommunityBoard']
    t_Area = row['Area']
    t_Census = row['Census']
    t_Neighborhood = row['Neighborhood']
    if t_CommunityBoard.startswith("Bronx"): t_Borough = 'Bronx'
    if t_CommunityBoard.startswith("Queens"): t_Borough = 'Queens'
    if t_CommunityBoard.startswith("Brooklyn"): t_Borough = 'Brooklyn'
    if t_CommunityBoard.startswith("Manhattan"): t_Borough = 'Manhattan'
    if t_CommunityBoard.startswith("Staten Island"): t_Borough = 'Staten Island'
    address = '{}, {}, NY'.format(t_Neighborhood,t_Borough)
    geolocator = Nominatim(user_agent="ny_explorer") 
    g = geolocator.geocode(address)
    if g != None : 
        latitude = g.latitude 
        longitude = g.longitude 
        #print(latitude,longitude) 
    else:
        latitude = '' 
        longitude = ''
    geo_bor = geo_bor.append({ 'Borough' : t_Borough,
                           'CommunityBoard' : row['CommunityBoard'],
                           'Area' : row['Area'],
                           'Neighborhood' : row['Neighborhood'],
                           'Census' : row['Census'],
                           'Neighborhood' : row['Neighborhood'],
                           'Latitude' : latitude,
                           'Longitude' : longitude
                         }, ignore_index=True)
               
geo_bor
# Out:
#            Borough      CommunityBoard   Area   Census      Neighborhood  \
# 0
# 1            Bronx          Bronx CB 1   7.17   91,497           Melrose
# 2            Bronx          Bronx CB 1   7.17   91,497        Mott Haven
# 3            Bronx          Bronx CB 1   7.17   91,497       Port Morris
# 4            Bronx          Bronx CB 2   5.54   52,246       Hunts Point
# ..             ...                 ...    ...      ...               ...
# 326  Staten Island  Staten Island CB 3  58.97  152,908      Prince's Bay
# 327  Staten Island  Staten Island CB 3  58.97  152,908   Richmond Valley
# 328  Staten Island  Staten Island CB 3  58.97  152,908         Rossville
# 329  Staten Island  Staten Island CB 3  58.97  152,908       Tottenville
# 330  Staten Island  Staten Island CB 3  58.97  152,908           Woodrow
#
#     Latitude Longitude
# 0    43.1562   -75.845
# 1    40.8257  -73.9152
# 2     40.809  -73.9229
# 3    40.8015  -73.9096
# 4    40.8126   -73.884
# ..       ...       ...
# 326   40.529  -74.1976
# 327  40.5201  -74.2293
# 328  40.5556  -74.2129
# 329  40.5112  -74.2493
# 330  40.5434  -74.1976
#
# [331 rows x 7 columns]

# %% [markdown]
# #### Visualize data in a map of all neighborhoods in NYC

# %%
geo_bor[geo_bor['Borough'] == ''].index
indexNames = geo_bor[ geo_bor['Borough'] == '' ].index
geo_bor.drop(indexNames , inplace=True)
geo_bor_filter = geo_bor[geo_bor['Latitude'] != '' ]

import folium
address01 = 'Manhattan, NY'
geolocator = Nominatim(user_agent="ny_explorer") 
location = geolocator.geocode(address01)
latt= location.latitude
long = location.longitude


# Instantiate map of NYC Boroughs
map_nyc = folium.Map(location=[latt,long],zoom_start=10)
for lat, lng, borough, neighborhood in zip( geo_bor_filter['Latitude'],
                                            geo_bor_filter['Longitude'],
                                            geo_bor_filter['Borough'],
                                            geo_bor_filter['Neighborhood']):
    label = '{}, {}'.format(neighborhood,borough)
    label = folium.Popup(label, parse_html =True)
    folium.CircleMarker(
                [lat,lng],
                radius=5,
                popup=label,
                color='blue',
                fill=True,
                fill_color='#3186cc',
                fill_opacity=0.7,
                parse_html=False).add_to(map_nyc)
    
map_nyc
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_3460fe9e69254c3ca2b780b1ff93c986%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_3460fe9e69254c3ca2b780b1ff93c986%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_3460fe9e69254c3ca2b780b1ff93c986%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_3460fe9e69254c3ca2b780b1ff93c986%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B40.7896239%2C-73.9598939%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2010%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ## Methodology <a name="methodology"></a>

# %% [markdown]
# In this project we will direct our efforts on detecting areas of Brooklyn that have low density of pharmacies, particularly in the borough of brooklyn.
#
# Once we do the exploratory analysis and then we will create kmeans clustering algorithm to group it into clusters for further analysis.

# %% [markdown]
# ### Analysis

# %% [markdown]
# Since the area we interested is brooklyn. We filter the data set.

# %%
geo_bor_brooklyn = geo_bor_filter[ geo_bor_filter['Borough'] == 'Brooklyn' ]
geo_bor_brooklyn.head()
# Out:
#      Borough CommunityBoard   Area   Census          Neighborhood Latitude  \
# 61  Brooklyn  Brooklyn CB 1  12.82  160,338            Greenpoint  40.7237
# 62  Brooklyn  Brooklyn CB 1  12.82  160,338          Williamsburg  40.7146
# 63  Brooklyn  Brooklyn CB 1  12.82  160,338   Williamsburg Houses  40.7096
# 64  Brooklyn  Brooklyn CB 2   7.72   98,620           Boerum Hill  40.6856
# 65  Brooklyn  Brooklyn CB 2   7.72   98,620      Brooklyn Heights  40.6961
#
#    Longitude
# 61   -73.951
# 62  -73.9535
# 63  -73.9419
# 64  -73.9842
# 65   -73.995

# %% [markdown]
# #### Foursquare
#
# Now that we have our location candidates, let's use Foursquare API to get info on pharmacies in each neighborhood.

# %%
#CLIENT_ID = 'VCVBVK4ZJW3YXYXGG0E0PHPAYZZY3FCKLDHVYQ2GUON25CBN' # your Foursquare ID
CLIENT_ID = '01V5YITO50521DZGP1LPOHU5UY2R2JHWHU3URE2QJNLNJV2R' # your Foursquare ID
#CLIENT_SECRET = 'EKKJXKVMOOPKJBQPG03G0DES5XA25B3XTMQVHYDZWRZQQ4KS' # your Foursquare Secret
CLIENT_SECRET = 'RMBOZLVD0PHGPWVD4XEXIJMGGW0QOHUGBNLPLAJX15ZQVIXQ' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value
radius = 250 # define radius
category = '4bf58dd8d48988d104941735'
col001 =['Borough','CommunityBoard','Area', 'Census', 'Neighborhood','Latitude',
                       'Longitude', 'Pharmacy_Name', 'Pharma_Latitude', 'Pharma_Longitude']
#Instantiate the dataframe
geo_bor_brooklyn_pharma = pd.DataFrame(columns=col001)

for index, row in geo_bor_brooklyn.iterrows():    
        lat = row['Latitude']
        lon = row['Longitude']
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&categoryId={}&radius={}&limit={}'.format(
        CLIENT_ID, 
        CLIENT_SECRET, 
        VERSION, 
        lat, 
        lon,
        category,
        radius, 
        LIMIT)          
        results = requests.get(url).json()['response']['groups'][0]['items']
        for item in results:
            item_pharma = item['venue']['name']
            item_lat = item['venue']['location']['lat']
            item_lng = item['venue']['location']['lng']
            geo_bor_brooklyn_pharma = geo_bor_brooklyn_pharma.append({ 'Borough' : row['Borough'],
                           'CommunityBoard' : row['CommunityBoard'],
                           'Area' : row['Area'],
                           'Neighborhood' : row['Neighborhood'],
                           'Census' : row['Census'],
                           'Neighborhood' : row['Neighborhood'],
                           'Latitude' : row['Latitude'],
                           'Longitude' : row['Longitude'],
                           'Pharmacy_Name' : item_pharma,
                           'Pharma_Latitude' : item_lat,
                           'Pharma_Longitude' : item_lng                                                                    
                         }, ignore_index=True)
    
geo_bor_brooklyn_pharma
# Out:
#       Borough  CommunityBoard   Area   Census  Neighborhood   Latitude  \
# 0    Brooklyn   Brooklyn CB 1  12.82  160,338    Greenpoint  40.723713
# 1    Brooklyn   Brooklyn CB 1  12.82  160,338    Greenpoint  40.723713
# 2    Brooklyn   Brooklyn CB 1  12.82  160,338    Greenpoint  40.723713
# 3    Brooklyn   Brooklyn CB 1  12.82  160,338    Greenpoint  40.723713
# 4    Brooklyn   Brooklyn CB 1  12.82  160,338    Greenpoint  40.723713
# ..        ...             ...    ...      ...           ...        ...
# 577  Brooklyn  Brooklyn CB 18  24.68  194,653   Mill Island  40.650104
# 578  Brooklyn  Brooklyn CB 18  24.68  194,653   Mill Island  40.650104
# 579  Brooklyn  Brooklyn CB 18  24.68  194,653   Mill Island  40.650104
# 580  Brooklyn  Brooklyn CB 18  24.68  194,653   Mill Island  40.650104
# 581  Brooklyn  Brooklyn CB 18  24.68  194,653   Mill Island  40.650104
#
#      Longitude                            Pharmacy_Name  Pharma_Latitude  \
# 0   -73.950971                 JAG-ONE Physical Therapy        40.725820
# 1   -73.950971                       Polska Przychodnia        40.724210
# 2   -73.950971                      Greenpoint Footcare        40.725489
# 3   -73.950971          Tribeca Pediatrics - Greenpoint        40.722475
# 4   -73.950971                       The Smilist Dental        40.724378
# ..         ...                                      ...              ...
# 577 -73.949582                Diamond Braces Church Ave        40.650555
# 578 -73.949582                   Advanced Dental Center        40.650555
# 579 -73.949582                           Diamond Braces        40.650555
# 580 -73.949582  Advanced Oral Surgery of Brooklyn, PLLC        40.650426
# 581 -73.949582                  Church Ave Orthadontics        40.650444
#
#      Pharma_Longitude
# 0          -73.951291
# 1          -73.949222
# 2          -73.950907
# 3          -73.949241
# 4          -73.948829
# ..                ...
# 577        -73.949753
# 578        -73.949753
# 579        -73.949753
# 580        -73.949818
# 581        -73.949796
#
# [582 rows x 10 columns]

# %%
geo_bor_brooklyn_pharma.head()
# Out:
#     Borough CommunityBoard   Area   Census Neighborhood   Latitude  Longitude  \
# 0  Brooklyn  Brooklyn CB 1  12.82  160,338   Greenpoint  40.723713 -73.950971
# 1  Brooklyn  Brooklyn CB 1  12.82  160,338   Greenpoint  40.723713 -73.950971
# 2  Brooklyn  Brooklyn CB 1  12.82  160,338   Greenpoint  40.723713 -73.950971
# 3  Brooklyn  Brooklyn CB 1  12.82  160,338   Greenpoint  40.723713 -73.950971
# 4  Brooklyn  Brooklyn CB 1  12.82  160,338   Greenpoint  40.723713 -73.950971
#
#                      Pharmacy_Name  Pharma_Latitude  Pharma_Longitude
# 0         JAG-ONE Physical Therapy        40.725820        -73.951291
# 1               Polska Przychodnia        40.724210        -73.949222
# 2              Greenpoint Footcare        40.725489        -73.950907
# 3  Tribeca Pediatrics - Greenpoint        40.722475        -73.949241
# 4               The Smilist Dental        40.724378        -73.948829

# %% [markdown]
# #### Explore the data set to find out the nearby pharmacies

# %%
geo_bor_brooklyn_pharma_cluster = geo_bor_brooklyn_pharma.groupby('Neighborhood').count()
geo_bor_brooklyn_pharma_cluster.head(10)
# Out:
#                    Borough  CommunityBoard  Area  Census  Latitude  Longitude  \
# Neighborhood
#  Bensonhurst            10              10    10      10        10         10
#  Brighton Beach         20              20    20      20        20         20
#  Brooklyn Heights       21              21    21      21        21         21
#  Canarsie               12              12    12      12        12         12
#  Clinton Hill            6               6     6       6         6          6
#  Cobble Hill             9               9     9       9         9          9
#  Coney Island            2               2     2       2         2          2
#  Cypress Hills           1               1     1       1         1          1
#  Dumbo                   5               5     5       5         5          5
#  East Flatbush           4               4     4       4         4          4
#
#                    Pharmacy_Name  Pharma_Latitude  Pharma_Longitude
# Neighborhood
#  Bensonhurst                  10               10                10
#  Brighton Beach               20               20                20
#  Brooklyn Heights             21               21                21
#  Canarsie                     12               12                12
#  Clinton Hill                  6                6                 6
#  Cobble Hill                   9                9                 9
#  Coney Island                  2                2                 2
#  Cypress Hills                 1                1                 1
#  Dumbo                         5                5                 5
#  East Flatbush                 4                4                 4

# %% [markdown]
# #### Cluster Neighborhoods
#
# Looking good. What we have now is a clear indication of zones with low number of pharmacies in vicinity. Let us now cluster those locations to create centers of zones containing good locations.

# %%
# import k-means from clustering stage
from sklearn.cluster import KMeans
kclusters = 10
# run k-means clustering
#geo_bor_brooklyn_pharma_cluster = geo_bor_brooklyn_pharma_cluster.drop('Neighborhood', 1)

kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(geo_bor_brooklyn_pharma_cluster)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([8, 2, 2, 4, 0, 8, 7, 7, 0, 5])

# %%
geo_bor_brooklyn_pharma_cluster.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
geo_bor_brooklyn_pharma_cluster
# Out:
#                       Cluster Labels  Borough  CommunityBoard  Area  Census  \
# Neighborhood
#  Bensonhurst                       8       10              10    10      10
#  Brighton Beach                    2       20              20    20      20
#  Brooklyn Heights                  2       21              21    21      21
#  Canarsie                          4       12              12    12      12
#  Clinton Hill                      0        6               6     6       6
#  Cobble Hill                       8        9               9     9       9
#  Coney Island                      7        2               2     2       2
#  Cypress Hills                     7        1               1     1       1
#  Dumbo                             0        5               5     5       5
#  East Flatbush                     5        4               4     4       4
#  Erasmus                           0        7               7     7       7
#  Flatlands                         4       13              13    13      13
#  Fort Greene                       2       20              20    20      20
#  Fort Hamilton                     0        7               7     7       7
#  Fulton Ferry                      7        1               1     1       1
#  Fulton Mall                       6       46              46    46      46
#  Georgetown                        9       17              17    17      17
#  Gerritsen Beach                   7        1               1     1       1
#  Gowanus                           7        1               1     1       1
#  Gravesend                         0        6               6     6       6
#  Homecrest                         4       13              13    13      13
#  Kensington                        8        8               8     8       8
#  Kings Bay                         5        3               3     3       3
#  Kings Highway                     1       60              60    60      60
#  Madison                           5        3               3     3       3
#  Mapleton                          7        1               1     1       1
#  Midwood                           5        4               4     4       4
#  Mill Island                       8        8               8     8       8
#  Ocean Parkway                     3       34              34    34      34
#  Park Slope                        3       30              30    30      30
#  Plum Beach                        9       15              15    15      15
#  Prospect Heights                  5        3               3     3       3
#  Remsen Village                    7        2               2     2       2
#  Rugby                             7        1               1     1       1
#  Stuyvesant Heights                0        6               6     6       6
#  Sunset Park                       0        6               6     6       6
#  Williamsburg Houses               5        3               3     3       3
#  Windsor Terrace                   5        4               4     4       4
#  Wingate                           8        8               8     8       8
# Bath Beach                         9       16              16    16      16
# Bay Ridge                          1       64              64    64      64
# Bedford-Stuyvesant                 5        3               3     3       3
# Bensonhurst                        8       10              10    10      10
# Bergen Beach                       5        4               4     4       4
# Boerum Hill                        9       16              16    16      16
# Borough Park                       5        4               4     4       4
# Brownsville                        5        3               3     3       3
# Bushwick                           7        1               1     1       1
# Carroll Gardens                    7        2               2     2       2
# Crown Heights                      4       12              12    12      12
# East Gravesend                     5        3               3     3       3
# Flatbush                           8       10              10    10      10
# Greenpoint                         4       11              11    11      11
# Greenwood Heights                  7        2               2     2       2
#
#                       Latitude  Longitude  Pharmacy_Name  Pharma_Latitude  \
# Neighborhood
#  Bensonhurst                10         10             10               10
#  Brighton Beach             20         20             20               20
#  Brooklyn Heights           21         21             21               21
#  Canarsie                   12         12             12               12
#  Clinton Hill                6          6              6                6
#  Cobble Hill                 9          9              9                9
#  Coney Island                2          2              2                2
#  Cypress Hills               1          1              1                1
#  Dumbo                       5          5              5                5
#  East Flatbush               4          4              4                4
#  Erasmus                     7          7              7                7
#  Flatlands                  13         13             13               13
#  Fort Greene                20         20             20               20
#  Fort Hamilton               7          7              7                7
#  Fulton Ferry                1          1              1                1
#  Fulton Mall                46         46             46               46
#  Georgetown                 17         17             17               17
#  Gerritsen Beach             1          1              1                1
#  Gowanus                     1          1              1                1
#  Gravesend                   6          6              6                6
#  Homecrest                  13         13             13               13
#  Kensington                  8          8              8                8
#  Kings Bay                   3          3              3                3
#  Kings Highway              60         60             60               60
#  Madison                     3          3              3                3
#  Mapleton                    1          1              1                1
#  Midwood                     4          4              4                4
#  Mill Island                 8          8              8                8
#  Ocean Parkway              34         34             34               34
#  Park Slope                 30         30             30               30
#  Plum Beach                 15         15             15               15
#  Prospect Heights            3          3              3                3
#  Remsen Village              2          2              2                2
#  Rugby                       1          1              1                1
#  Stuyvesant Heights          6          6              6                6
#  Sunset Park                 6          6              6                6
#  Williamsburg Houses         3          3              3                3
#  Windsor Terrace             4          4              4                4
#  Wingate                     8          8              8                8
# Bath Beach                  16         16             16               16
# Bay Ridge                   64         64             64               64
# Bedford-Stuyvesant           3          3              3                3
# Bensonhurst                 10         10             10               10
# Bergen Beach                 4          4              4                4
# Boerum Hill                 16         16             16               16
# Borough Park                 4          4              4                4
# Brownsville                  3          3              3                3
# Bushwick                     1          1              1                1
# Carroll Gardens              2          2              2                2
# Crown Heights               12         12             12               12
# East Gravesend               3          3              3                3
# Flatbush                    10         10             10               10
# Greenpoint                  11         11             11               11
# Greenwood Heights            2          2              2                2
#
#                       Pharma_Longitude
# Neighborhood
#  Bensonhurst                        10
#  Brighton Beach                     20
#  Brooklyn Heights                   21
#  Canarsie                           12
#  Clinton Hill                        6
#  Cobble Hill                         9
#  Coney Island                        2
#  Cypress Hills                       1
#  Dumbo                               5
#  East Flatbush                       4
#  Erasmus                             7
#  Flatlands                          13
#  Fort Greene                        20
#  Fort Hamilton                       7
#  Fulton Ferry                        1
#  Fulton Mall                        46
#  Georgetown                         17
#  Gerritsen Beach                     1
#  Gowanus                             1
#  Gravesend                           6
#  Homecrest                          13
#  Kensington                          8
#  Kings Bay                           3
#  Kings Highway                      60
#  Madison                             3
#  Mapleton                            1
#  Midwood                             4
#  Mill Island                         8
#  Ocean Parkway                      34
#  Park Slope                         30
#  Plum Beach                         15
#  Prospect Heights                    3
#  Remsen Village                      2
#  Rugby                               1
#  Stuyvesant Heights                  6
#  Sunset Park                         6
#  Williamsburg Houses                 3
#  Windsor Terrace                     4
#  Wingate                             8
# Bath Beach                          16
# Bay Ridge                           64
# Bedford-Stuyvesant                   3
# Bensonhurst                         10
# Bergen Beach                         4
# Boerum Hill                         16
# Borough Park                         4
# Brownsville                          3
# Bushwick                             1
# Carroll Gardens                      2
# Crown Heights                       12
# East Gravesend                       3
# Flatbush                            10
# Greenpoint                          11
# Greenwood Heights                    2

# %% [markdown]
# #### Now the kmeans has clustered the data set based on the density
#
# Filter the dataset for cluster with lowest density

# %%
geo_bor_brooklyn_pharma_recom = geo_bor_brooklyn_pharma_cluster.loc[geo_bor_brooklyn_pharma_cluster['Cluster Labels'] == 7]

# %%
geo_bor_brooklyn_pharma_recom
# Out:
#                    Cluster Labels  Borough  CommunityBoard  Area  Census  \
# Neighborhood
#  Coney Island                   7        2               2     2       2
#  Cypress Hills                  7        1               1     1       1
#  Fulton Ferry                   7        1               1     1       1
#  Gerritsen Beach                7        1               1     1       1
#  Gowanus                        7        1               1     1       1
#  Mapleton                       7        1               1     1       1
#  Remsen Village                 7        2               2     2       2
#  Rugby                          7        1               1     1       1
# Bushwick                        7        1               1     1       1
# Carroll Gardens                 7        2               2     2       2
# Greenwood Heights               7        2               2     2       2
#
#                    Latitude  Longitude  Pharmacy_Name  Pharma_Latitude  \
# Neighborhood
#  Coney Island             2          2              2                2
#  Cypress Hills            1          1              1                1
#  Fulton Ferry             1          1              1                1
#  Gerritsen Beach          1          1              1                1
#  Gowanus                  1          1              1                1
#  Mapleton                 1          1              1                1
#  Remsen Village           2          2              2                2
#  Rugby                    1          1              1                1
# Bushwick                  1          1              1                1
# Carroll Gardens           2          2              2                2
# Greenwood Heights         2          2              2                2
#
#                    Pharma_Longitude
# Neighborhood
#  Coney Island                     2
#  Cypress Hills                    1
#  Fulton Ferry                     1
#  Gerritsen Beach                  1
#  Gowanus                          1
#  Mapleton                         1
#  Remsen Village                   2
#  Rugby                            1
# Bushwick                          1
# Carroll Gardens                   2
# Greenwood Heights                 2

# %% [markdown]
# #### Visualize the dataset based on the recommendation consolidated by the algorithm

# %%
column_final = ['Borough','Neighborhood','Latitude', 'Longitude']
#Instantiate the dataframe
geo_bor_brooklyn_pharma_recom_visual = pd.DataFrame(columns=column_final)

for index, row in geo_bor_brooklyn_pharma_recom.iterrows():
    t_fNeighborhood = index
    t_fBorough='Brooklyn'
    address = '{}, {}, NY'.format(t_Neighborhood,t_Borough)
    geolocator = Nominatim(user_agent="nybk_explorer") 
    g = geolocator.geocode(address)
    if g != None : 
        latitude = g.latitude 
        longitude = g.longitude 
        #print(latitude,longitude) 
    else:
        latitude = '' 
        longitude = ''
    geo_bor_brooklyn_pharma_recom_visual = geo_bor_brooklyn_pharma_recom_visual.append({ 'Borough' : t_fBorough,
                           'Neighborhood' : t_fNeighborhood,
                           'Latitude' : latitude,
                           'Longitude' : longitude
                         }, ignore_index=True)
               
geo_bor_brooklyn_pharma_recom_visual
# Out:
#      Borough       Neighborhood   Latitude  Longitude
# 0   Brooklyn       Coney Island  40.543439 -74.197644
# 1   Brooklyn      Cypress Hills  40.543439 -74.197644
# 2   Brooklyn       Fulton Ferry  40.543439 -74.197644
# 3   Brooklyn    Gerritsen Beach  40.543439 -74.197644
# 4   Brooklyn            Gowanus  40.543439 -74.197644
# 5   Brooklyn           Mapleton  40.543439 -74.197644
# 6   Brooklyn     Remsen Village  40.543439 -74.197644
# 7   Brooklyn              Rugby  40.543439 -74.197644
# 8   Brooklyn           Bushwick  40.543439 -74.197644
# 9   Brooklyn    Carroll Gardens  40.543439 -74.197644
# 10  Brooklyn  Greenwood Heights  40.543439 -74.197644

# %% [markdown]
# ## Results and Discussion <a name="results"></a>
#
# After reviewing the pharmacies across the Brooklyn neighborhoods the above locations came out as the least number of pharmacies.
#
# This, of course, does not imply that those zones are actually optimal locations for a new Pharmacy!
#
# Purpose of this analysis was to only provide info on areas in Brooklyn where a new pharmacy can be established
# This will give an initial list of optimal locations to stakeholders where a further deep evaluation will be required to nail down the location considering additional factors.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# Purpose of this project was to identify areas in Brooklyn with low number of pharmacies in order to aid stakeholders in narrowing down the search for optimal location.
# By calculating density distribution from Foursquare data we have first identified general boroughs that justify further analysis, and then generated extensive collection of locations which satisfy some basic requirements regarding existing nearby pharmacies.
# Clustering of those locations was then performed in order to create major zones of interest (containing greatest number of potential locations) to be used as starting points for final exploration by stakeholders.
#
# Final decission on optimal location will be made by stakeholders based on specific characteristics of neighborhoods and locations in every recommended zone,
# taking into consideration additional factors like attractiveness of each location, zoning, city approvals, proximity to hospitals, real estate availability, prices etc.
